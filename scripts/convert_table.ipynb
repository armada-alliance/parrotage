# %%
import pandas as pd
import re
import os
from io import StringIO


# Read the Markdown file and extract the table as a string
# path = os.path.dirname(os.path.abspath('sources_table'))
with open('../sources_table/sources.md', 'r') as f:
    markdown_text = f.read()

table_match = re.search(r'\|(.+)\|[\n|\r\n]\|(.+)\|[\n|\r\n](\|[-:| ]+\|[\n|\r\n])*((\|.+[\n|\r\n])+)', markdown_text)
table_text = table_match.group()

# Convert the table string to a pandas DataFrame and then to CSV
df = pd.read_csv(StringIO(table_text), sep='|', header=0, engine='python')

# We need to drop the first and fifth column, which is empty and then remove the first row, which is the header
df_clean = df.drop(df.columns[[0, 4]], axis=1)
df_clean = df_clean.drop(df_clean.index[0])

# almost there XD now we need to format the url column by removing everything inside the brackets
df_clean[' Url '] = df_clean[' Url '].str.replace(r'\[.*\]', '', regex=True).str.replace(r'\(|\)', '', regex=True)


csv_text = df_clean.to_csv(index=False)

# Write the CSV to a file
with open('../sources_table/sources.csv', 'w') as f:
    f.write(csv_text)

# %%
df
# Out:
#     Unnamed: 0                                               Url       Type   \
# 0          NaN                                                ---        ---
# 1          NaN          [CIP website](https://cips.cardano.org/)    Website
# 2          NaN   [CIP GitHub Repo](https://github.com/cardano-...    Github
# 3          NaN   [https://www.nginx.com/wp-content/uploads/201...   Website
# 4          NaN   [https://www.freecodecamp.org/news/the-nginx-...   Website
# 5          NaN   [http://www.dest-unreach.org/socat/doc/socat....   Website
# 6          NaN   [https://www.hackingarticles.in/socat-for-pen...   Website
# 7          NaN   [https://www.safe.security/assets/img/researc...   Website
# 8          NaN   [https://manpages.ubuntu.com/manpages/jammy/e...   Website
# 9          NaN   [https://manpages.ubuntu.com/manpages/bionic/...   Website
# 10         NaN   [https://www.hackingarticles.in/port-forwardi...   Website
# 11         NaN   [https://www.hackingarticles.in/comprehensive...   Website
# 12         NaN   [https://www.hackingarticles.in/comprehensive...   Website
# 13         NaN   [https://www.hackingarticles.in/comprehensive...   Website
# 14         NaN   [https://www.hackingarticles.in/network-scann...   Website
# 15         NaN   [https://www.hackingarticles.in/nmap-for-pent...   Website
# 16         NaN   [https://www.hackingarticles.in/nmap-for-pent...   Website
# 17         NaN   [https://www.hackingarticles.in/nmap-for-pent...   Website
# 18         NaN   [https://www.hackingarticles.in/nmap-for-pent...   Website
# 19         NaN   [https://www.hackingarticles.in/understanding...   Website
# 20         NaN   [https://www.hackingarticles.in/understanding...   Website
# 21         NaN   [https://docs.oracle.com/en-us/iaas/Content/N...   Website
# 22         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 23         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 24         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 25         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 26         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 27         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 28         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 29         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 30         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 31         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 32         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 33         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 34         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
# 35         NaN   [https://docs.oracle.com/en-us/iaas/Content/B...   Website
#
#       Description (optional)   Unnamed: 4
# 0                         ---         NaN
# 1      CIP Standards website          NaN
# 2                 CIP Github          NaN
# 3             nginx cookbook          NaN
# 4             nginx handbook          NaN
# 5           socat networking          NaN
# 6                 more socat          NaN
# 7         UFW firewall Guide          NaN
# 8                UFW manpage          NaN
# 9          rinetd networking          NaN
# 10           port forwarding          NaN
# 11                 tcpdump 1          NaN
# 12                 tcpdump 2          NaN
# 13                 tcpdump 3          NaN
# 14            nmap beginners          NaN
# 15                    nmap 1          NaN
# 16                    nmap 2          NaN
# 17                    nmap 3          NaN
# 18                    nmap 4          NaN
# 19           nmap/firewall 1          NaN
# 20           nmap/firewall 2          NaN
# 21   Oracle Cloud Networking          NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# 30                                    NaN
# 31                                    NaN
# 32                                    NaN
# 33                                    NaN
# 34                                    NaN
# 35                                    NaN

# %%
# get column names
df.columns
# Out:
# Index(['Unnamed: 0', ' Url ', ' Type ', ' Description (optional) ',
#        'Unnamed: 4'],
#       dtype='object')

# %%
# We need to drop the first and fifth column, which is empty and then remove the first row, which is the header
df_clean = df.drop(df.columns[[0, 4]], axis=1)
df_clean = df_clean.drop(df_clean.index[0])

# almost there XD now we need to format the url column by removing everything inside the brackets
df_clean[' Url '] = df_clean[' Url '].str.replace(r'\[.*\]', '', regex=True).str.replace(r'\(|\)', '', regex=True)
